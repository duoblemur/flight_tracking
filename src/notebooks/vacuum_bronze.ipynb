# %%
# Vacuum bronze table to remove files older than retention threshold
# Table properties set delta.deletedFileRetentionDuration = 1 hour

TARGET_TABLE = "dbr_dev.skybound_bronze.flights_bronze"

spark.sql(f"VACUUM {TARGET_TABLE}")
print(f"VACUUM completed for {TARGET_TABLE}")
